# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization, Conv2D, Dense, Dropout, MaxPooling2D, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import SGD

# %%
train = pd.read_csv(r"train.csv")

# %%
train
# Out:
#        pixel_0  pixel_1  pixel_2  pixel_3  pixel_4  pixel_5  pixel_6  pixel_7  \
# 0           59       43       50       68       98      119      139      145
# 1          154      126      105      102      125      155      172      180
# 2          255      253      253      253      253      253      253      253
# 3           28       37       38       42       44       40       40       24
# 4          170      168      177      183      181      177      181      184
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 49995      145      151      156      155      153      153      157      161
# 49996      255      254      255      254      254      254      254      253
# 49997       35       40       42       39       43       45       48       51
# 49998      189      186      185      184      182      181      180      180
# 49999      229      236      234      231      236      242      246      246
#
#        pixel_8  pixel_9  ...  pixel_3063  pixel_3064  pixel_3065  pixel_3066  \
# 0          149      149  ...          58          65          59          46
# 1          142      111  ...          42          67         101         122
# 2          253      253  ...          83          80          69          66
# 3           32       43  ...          39          59          42          44
# 4          189      189  ...          88          85          82          83
# ...        ...      ...  ...         ...         ...         ...         ...
# 49995      161      161  ...          68          64          61          63
# 49996      254      254  ...          61          64          68          64
# 49997       53       56  ...          94         104         103          96
# 49998      181      180  ...         166         171         171         172
# 49999      242      236  ...         141         147         158         168
#
#        pixel_3067  pixel_3068  pixel_3069  pixel_3070  pixel_3071  label
# 0              57         104         140          84          72      6
# 1             133         136         139         142         144      9
# 2              72          79          83          83          84      9
# 3              48          38          28          37          46      4
# 4              79          78          82          78          80      1
# ...           ...         ...         ...         ...         ...    ...
# 49995          59          57          56          53          54      2
# 49996          76          82          79          81          76      6
# 49997          93          87          77          66          50      9
# 49998         169         165         169         171         171      1
# 49999         171         174         173         162         161      1
#
# [50000 rows x 3073 columns]

# %%
x_train = train.drop(['label'], axis = 1).values
y_train = train['label'].values

# %%
x_train.shape
# Out:
# (50000, 3072)

# %%
x_train = x_train.reshape((50000, 32, 32, 3)).astype('float32')/255

# %%
test = pd.read_csv(r"test.csv")

# %%
test
# Out:
#       pixel_0  pixel_1  pixel_2  pixel_3  pixel_4  pixel_5  pixel_6  pixel_7  \
# 0         158      159      165      166      160      156      162      159
# 1         235      231      232      232      232      232      232      232
# 2         158      158      139      132      166      182      187      193
# 3         155      167      176      190      177      166      168      166
# 4          65       70       48       30       23       40       44       45
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 9995       76       76       77       76       75       76       76       76
# 9996       81       91       98      106      108      110       80       84
# 9997       20       19       15       15       14       13       12       11
# 9998       25       15       23       17       23       51       74       91
# 9999       73       98       99       77       59      146      214      176
#
#       pixel_8  pixel_9  ...  pixel_3062  pixel_3063  pixel_3064  pixel_3065  \
# 0         158      159  ...         130         123         145         167
# 1         232      232  ...         108         117         123         133
# 2         199      205  ...          45          46          44          44
# 3         170      179  ...          52          55          70         103
# 4          45       40  ...         102         127         156         139
# ...       ...      ...  ...         ...         ...         ...         ...
# 9995       76       78  ...         228         185         177         223
# 9996       88       90  ...         126         107         143         155
# 9997       10        9  ...         114         112          68          50
# 9998      114      137  ...          87          84          83          84
# 9999      125      218  ...          84          89          88          85
#
#       pixel_3066  pixel_3067  pixel_3068  pixel_3069  pixel_3070  pixel_3071
# 0            182         175         145         124         129         110
# 1            141         153         163         178         191         199
# 2             43          52          37           8           3           7
# 3            105          72          53          50          52          50
# 4            131         130         147         136         146         117
# ...          ...         ...         ...         ...         ...         ...
# 9995         239         239         235         236         234         236
# 9996         156         160         173         129         147         160
# 9997          52          52          51          50          53          47
# 9998          79          78          78          80          81          80
# 9999          93          93          90          94          58          26
#
# [10000 rows x 3072 columns]

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape = (32,32,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3),activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation = 'softmax'))

sgd = SGD(learning_rate = 0.1)
model.compile(optimizer= sgd, loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# C:\Users\Pranavd\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       802,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 823,050 (3.14 MB)
#  Trainable params: 822,986 (3.14 MB)
#  Non-trainable params: 64 (256.00 B)

# %%
r = model.fit(x_train, y_train, validation_split=0.2, epochs = 11, batch_size = 64)
# Out:
# Epoch 1/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.2148 - loss: 2.3086 - val_accuracy: 0.4060 - val_loss: 1.6055
# Epoch 2/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.3938 - loss: 1.6383 - val_accuracy: 0.4728 - val_loss: 1.4908
# Epoch 3/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.4598 - loss: 1.4805 - val_accuracy: 0.5288 - val_loss: 1.3507
# Epoch 4/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.5130 - loss: 1.3551 - val_accuracy: 0.5743 - val_loss: 1.2162
# Epoch 5/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 45ms/step - accuracy: 0.5507 - loss: 1.2622 - val_accuracy: 0.5623 - val_loss: 1.2762
# Epoch 6/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 45ms/step - accuracy: 0.5791 - loss: 1.1754 - val_accuracy: 0.5445 - val_loss: 1.2850
# Epoch 7/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.6111 - loss: 1.0886 - val_accuracy: 0.5776 - val_loss: 1.2253
# Epoch 8/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 44ms/step - accuracy: 0.6392 - loss: 1.0055 - val_accuracy: 0.5869 - val_loss: 1.2003
# Epoch 9/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 44ms/step - accuracy: 0.6774 - loss: 0.9078 - val_accuracy: 0.5935 - val_loss: 1.2426
# Epoch 10/11
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 44ms/step - accuracy: 0.6968 - loss: 0.8446 - val_accuracy: 0.5973 - val_loss: 1.2216
# Epoch 11/11
# 587/625 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7267 - loss: 0.7648

# %%
x_test = test.values

# %%
x_test = x_test.reshape((10000, 32, 32, 3)).astype('float32')/255

# %%
predictions = model.predict(x_test)

# %%
predictions

# %%
r.history.keys()

# %%
plt.plot(r.history['accuracy'], label = 'accuracy', color = 'green')
plt.plot(r.history['val_accuracy'], label = 'val_accuracy', color = 'red')
plt.legend()

# %%
plt.plot(r.history['loss'], label = 'loss', color = 'red')
plt.plot(r.history['val_loss'], label = 'val_loss', color = 'blue')
plt.legend()
